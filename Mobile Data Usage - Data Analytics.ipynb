# %%
import pandas as pd
import numpy as np

# %%
event_data = pd.read_csv('event_data.csv', dtype={'device_id': str})

# %%
event_data.tail()
# Out:
#         event_id             device_id            timestamp  longitude  \
# 534410   1930098   8076952602619385461  2016-05-07 10:00:49  76.826195
# 534411   1919095  -4969474265401848066  2016-05-05 00:29:56  76.846153
# 534412   2608925   3743400887497188525  2016-05-06 08:30:00  76.861488
# 534413   3001451  -4436186230350990184  2016-05-01 15:12:29  76.813683
# 534414   3229508  -4923978208941087520  2016-05-01 10:08:12  76.847328
#
#          latitude        city       state
# 534410  30.772198  Chandigarh  Chandigarh
# 534411  30.830111  Chandigarh  Chandigarh
# 534412  30.826464  Chandigarh  Chandigarh
# 534413  30.785307  Chandigarh  Chandigarh
# 534414  30.845663  Chandigarh  Chandigarh

# %%
event_data.shape
# Out:
# (534415, 8)

# %%
event_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 534415 entries, 0 to 534414
# Data columns (total 7 columns):
# event_id     534415 non-null int64
# device_id    534352 non-null object
# timestamp    534415 non-null object
# longitude    534352 non-null float64
# latitude     534352 non-null float64
# city         534415 non-null object
# state        534415 non-null object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 28.5+ MB

# %%
event_data.describe(include='all')
# Out:
#             event_id            device_id            timestamp      longitude  \
# count   5.344150e+05               534352               534415  534352.000000
# unique           NaN                 9563               345583            NaN
# top              NaN  5536513450525271144  2016-05-07 22:35:20            NaN
# freq             NaN                33405                    9            NaN
# mean    1.629986e+06                  NaN                  NaN      80.041638
# std     9.387003e+05                  NaN                  NaN       1.438010
# min     2.000000e+00                  NaN                  NaN      12.567400
# 25%     8.168485e+05                  NaN                  NaN      80.282196
# 50%     1.633103e+06                  NaN                  NaN      80.313164
# 75%     2.442676e+06                  NaN                  NaN      80.351685
# max     3.252950e+06                  NaN                  NaN      94.036461
#
#              latitude     city      state
# count   534352.000000   534415     534415
# unique            NaN      202          6
# top               NaN  Chennai  TamilNadu
# freq              NaN   366828     436282
# mean        15.523034      NaN        NaN
# std          5.733225      NaN        NaN
# min          8.190110      NaN        NaN
# 25%         13.118649      NaN        NaN
# 50%         13.145584      NaN        NaN
# 75%         13.179580      NaN        NaN
# max         41.871899      NaN        NaN

# %%
gender_age_train = pd.read_csv('gender_age_train.csv', dtype={'device_id': str})

# %%
gender_age_train.head()
# Out:
#               device_id gender  age   group
# 0  -8076087639492063270      M   35  M32-38
# 1  -2897161552818060146      M   35  M32-38
# 2  -8260683887967679142      M   35  M32-38
# 3  -4938849341048082022      M   30  M29-31
# 4    245133531816851882      M   30  M29-31

# %%
gender_age_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74645 entries, 0 to 74644
# Data columns (total 4 columns):
# device_id    74645 non-null object
# gender       74645 non-null object
# age          74645 non-null int64
# group        74645 non-null object
# dtypes: int64(1), object(3)
# memory usage: 2.3+ MB

# %%
gender_age_train.describe(include='all')
# Out:
#                   device_id gender           age   group
# count                 74645  74645  74645.000000   74645
# unique                74645      2           NaN      12
# top     7891586392738349235      M           NaN  M23-26
# freq                      1  47904           NaN    9605
# mean                    NaN    NaN     31.410342     NaN
# std                     NaN    NaN      9.868735     NaN
# min                     NaN    NaN      1.000000     NaN
# 25%                     NaN    NaN     25.000000     NaN
# 50%                     NaN    NaN     29.000000     NaN
# 75%                     NaN    NaN     36.000000     NaN
# max                     NaN    NaN     96.000000     NaN

# %%
phone_brand_device_model = pd.read_csv('phone_brand_device_model.csv', dtype={'device_id': str})

# %%
phone_brand_device_model.head()
# Out:
#               device_id phone_brand device_model
# 0   1877775838486905855        vivo          Y13
# 1  -3766087376657242966          小米         V183
# 2  -6238937574958215831        OPPO          R7s
# 3   8973197758510677470          三星        A368t
# 4  -2015528097870762664          小米      红米Note2

# %%
phone_brand_device_model.shape
# Out:
# (87726, 3)

# %%
phone_brand_device_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87726 entries, 0 to 87725
# Data columns (total 3 columns):
# device_id       87726 non-null object
# phone_brand     87726 non-null object
# device_model    87726 non-null object
# dtypes: object(3)
# memory usage: 2.0+ MB

# %%
phone_brand_device_model.describe(include='all')
# Out:
#                    device_id phone_brand device_model
# count                  87726       87726        87726
# unique                 87726         116         1467
# top     -4772624663141447229          小米       红米note
# freq                       1       21645         3500

# %% [markdown]
# ## Process data to filter irrelevant values

# %%
device_ids = event_data['device_id'].unique()

# %%
device_ids.shape
# Out:
# (9564,)

# %%
device_ids
# Out:
# array(['-2638302274530537957', '2687021466923970058',
#        '-5080051514408049802', ..., '3743400887497188525',
#        '-4436186230350990184', '-4923978208941087520'], dtype=object)

# %%
device_id_data= pd.DataFrame({'device_id': device_ids})

# %%
device_id_data.shape
# Out:
# (9564, 1)

# %%
gender_age_train=device_id_data.merge(gender_age_train,on='device_id', how='left')

# %%
gender_age_train.shape
# Out:
# (9564, 4)

# %%
gender_age_train.head()
# Out:
#               device_id gender   age   group
# 0  -2638302274530537957      F  29.0  F29-32
# 1   2687021466923970058      F  25.0  F24-26
# 2  -5080051514408049802      F  27.0  F27-28
# 3  -4909264578655508813      M  19.0    M22-
# 4   -965141125520486405      F  38.0  F33-42

# %%
phone_brand_device_model=device_id_data.merge(phone_brand_device_model,on='device_id', how='left')

# %%
phone_brand_device_model.shape
# Out:
# (9564, 3)

# %%
phone_brand_device_model.head()
# Out:
#               device_id phone_brand    device_model
# 0  -2638302274530537957          三星  Galaxy Grand 2
# 1   2687021466923970058          酷比              M1
# 2  -5080051514408049802          小米          小米note
# 3  -4909264578655508813          三星           A788t
# 4   -965141125520486405          魅族        魅蓝Note 2

# %% [markdown]
# ### Data cleanup

# %%
event_data[pd.isnull(event_data['device_id'])]
# Out:
#         event_id device_id            timestamp  longitude   latitude  \
# 170221     58816       NaN  2016-05-03 21:00:59  80.309273  13.149176
# 170233     62553       NaN  2016-05-04 23:23:44  80.309273  13.149176
# 170265     97365       NaN  2016-05-07 17:19:14  80.309273  13.149176
# 170506    315532       NaN  2016-05-04 18:48:01  80.309273  13.149176
# 170697    477494       NaN  2016-05-02 01:29:26  80.309273  13.149176
# 170950    736821       NaN  2016-05-02 14:13:53  80.309273  13.149176
# 171069    827477       NaN  2016-05-04 21:21:22  80.309273  13.149176
# 171259   1003190       NaN  2016-05-07 02:08:49  80.309273  13.149176
# 171351   1098429       NaN  2016-05-02 19:08:36  80.309273  13.149176
# 171420   1158454       NaN  2016-05-07 19:25:11  80.309273  13.149176
# 171630   1345666       NaN  2016-05-05 18:07:07  80.309273  13.149176
# 171717   1432894       NaN  2016-05-06 18:43:17  80.309273  13.149176
# 175889     55138       NaN  2016-05-02 19:12:48  80.335434  13.189053
# 388288   2751541       NaN  2016-05-06 13:16:52  80.343613  13.153332
# 388507   2949050       NaN  2016-05-04 16:55:44  80.343613  13.153332
# 388713   3146895       NaN  2016-05-02 11:49:39  80.343613  13.153332
#
#            city      state
# 170221  Chennai  TamilNadu
# 170233  Chennai  TamilNadu
# 170265  Chennai  TamilNadu
# 170506  Chennai  TamilNadu
# 170697  Chennai  TamilNadu
# 170950  Chennai  TamilNadu
# 171069  Chennai  TamilNadu
# 171259  Chennai  TamilNadu
# 171351  Chennai  TamilNadu
# 171420  Chennai  TamilNadu
# 171630  Chennai  TamilNadu
# 171717  Chennai  TamilNadu
# 175889  Chennai  TamilNadu
# 175901  Chennai  TamilNadu
# 175933  Chennai  TamilNadu
# 176174  Chennai  TamilNadu
# 176365  Chennai  TamilNadu
# 176618  Chennai  TamilNadu
# 176737  Chennai  TamilNadu
# 176927  Chennai  TamilNadu
# 177019  Chennai  TamilNadu
# 177088  Chennai  TamilNadu
# 177298  Chennai  TamilNadu
# 177385  Chennai  TamilNadu
# 200756  Chennai  TamilNadu
# 200768  Chennai  TamilNadu
# 200800  Chennai  TamilNadu
# 201041  Chennai  TamilNadu
# 201232  Chennai  TamilNadu
# 201485  Chennai  TamilNadu
# ...         ...        ...
# 201955  Chennai  TamilNadu
# 202165  Chennai  TamilNadu
# 202252  Chennai  TamilNadu
# 354388  Chennai  TamilNadu
# 354473  Chennai  TamilNadu
# 354516  Chennai  TamilNadu
# 354824  Chennai  TamilNadu
# 355077  Chennai  TamilNadu
# 355193  Chennai  TamilNadu
# 355626  Chennai  TamilNadu
# 355845  Chennai  TamilNadu
# 356051  Chennai  TamilNadu
# 360333  Chennai  TamilNadu
# 360418  Chennai  TamilNadu
# 360461  Chennai  TamilNadu
# 360769  Chennai  TamilNadu
# 361022  Chennai  TamilNadu
# 361138  Chennai  TamilNadu
# 361571  Chennai  TamilNadu
# 361790  Chennai  TamilNadu
# 361996  Chennai  TamilNadu
# 387050  Chennai  TamilNadu
# 387135  Chennai  TamilNadu
# 387178  Chennai  TamilNadu
# 387486  Chennai  TamilNadu
# 387739  Chennai  TamilNadu
# 387855  Chennai  TamilNadu
# 388288  Chennai  TamilNadu
# 388507  Chennai  TamilNadu
# 388713  Chennai  TamilNadu
#
# [63 rows x 7 columns]

# %%
event_data.dropna(subset=['device_id'], inplace=True)

# %%
event_data[pd.isnull(event_data['device_id'])]
# Out:
# Empty DataFrame
# Columns: [event_id, device_id, timestamp, longitude, latitude, city, state]
# Index: []

# %%
event_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 534352 entries, 0 to 534414
# Data columns (total 7 columns):
# event_id     534352 non-null int64
# device_id    534352 non-null object
# timestamp    534352 non-null object
# longitude    534289 non-null float64
# latitude     534289 non-null float64
# city         534352 non-null object
# state        534352 non-null object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 32.6+ MB

# %%
gender_age_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9564 entries, 0 to 9563
# Data columns (total 4 columns):
# device_id    9563 non-null object
# gender       9563 non-null object
# age          9563 non-null float64
# group        9563 non-null object
# dtypes: float64(1), object(3)
# memory usage: 373.6+ KB

# %%
phone_brand_device_model.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9564 entries, 0 to 9563
# Data columns (total 3 columns):
# device_id       9563 non-null object
# phone_brand     9563 non-null object
# device_model    9563 non-null object
# dtypes: object(3)
# memory usage: 298.9+ KB
